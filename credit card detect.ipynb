# %%
import numpy as np
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import os
df = pd.read_csv(r"C:\Users\Buymacs\OneDrive\Desktop\creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.628620e-16 -3.576577e-16  2.618565e-16  4.473914e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.109395e-16  1.686100e-15 -3.661401e-16 -1.227452e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
class_counts = df['Class'].value_counts()
class_counts
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
class_percentages = df['Class'].value_counts(normalize=True) * 100
class_percentages
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.drop_duplicates()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [283726 rows x 31 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))
sns.histplot(df['Amount'], bins=100, ax=ax1, kde=True)
ax1.set_title('Distribution of Transaction Amount')
sns.histplot(df['Time'], bins=100, ax=ax2, kde=True)
ax2.set_title('Distribution of Transaction Time')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))


sns.boxplot(x='Class', y='Amount', data=df, ax=ax1)
ax1.set_title('Boxplot of Amount by Transaction Class')
ax1.set_ylabel('Amount Value')
ax1.set_xlabel('Class (0 = No Fraud, 1 = Fraud)') 


sns.boxplot(x='Class', y='Time', data=df, ax=ax2)
ax2.set_title('Boxplot of Time by Transaction Class')
ax2.set_ylabel('Time Value')
ax2.set_xlabel('Class (0 = No Fraud, 1 = Fraud)')

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(14, 6))


sns.kdeplot(df[df['Class'] == 0]['Amount'], label='Class 0 (No Fraud)', shade=True, ax=ax1)
sns.kdeplot(df[df['Class'] == 1]['Amount'], label='Class 1 (Fraud)', shade=True, ax=ax1)
ax1.set_title('KDE Plot for Amount by Class')
ax1.set_xlabel('Amount Value')
ax1.legend()


sns.kdeplot(df[df['Class'] == 0]['Time'], label='Class 0 (No Fraud)', shade=True, ax=ax2)
sns.kdeplot(df[df['Class'] == 1]['Time'], label='Class 1 (Fraud)', shade=True, ax=ax2)
ax2.set_title('KDE Plot for Time by Class')
ax2.set_xlabel('Time Value')
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Buymacs\AppData\Local\Temp\ipykernel_9348\3434852055.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['Class'] == 0]['Amount'], label='Class 0 (No Fraud)', shade=True, ax=ax1)
# C:\Users\Buymacs\AppData\Local\Temp\ipykernel_9348\3434852055.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['Class'] == 1]['Amount'], label='Class 1 (Fraud)', shade=True, ax=ax1)
# C:\Users\Buymacs\AppData\Local\Temp\ipykernel_9348\3434852055.py:11: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['Class'] == 0]['Time'], label='Class 0 (No Fraud)', shade=True, ax=ax2)
# C:\Users\Buymacs\AppData\Local\Temp\ipykernel_9348\3434852055.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df['Class'] == 1]['Time'], label='Class 1 (Fraud)', shade=True, ax=ax2)

# %%
plt.figure(figsize=(10, 6))


plt.scatter(df['Time'], df['Amount'], alpha=0.5)


plt.xlabel('Time') # Corrected label
plt.ylabel('Amount') # Corrected label
plt.title('Scatter Plot of Time vs. Amount')

plt.savefig('direct_correction_scatter.png')

# %%
df_sample = df.sample(n=5000, random_state=42)

plt.figure(figsize=(12, 7))

sns.scatterplot(x='Time', y='Amount', hue='Class', data=df_sample, 
                style='Class', s=100, alpha=0.7)
                
plt.title('Scatter Plot of Time vs. Amount (Sampled Data, Colored by Class)')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.legend(title='Class')
plt.grid(True)

plt.savefig('improved_seaborn_scatter.png')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class', axis=1),
                                                    df['Class'],
                                                    test_size=0.2,
                                                    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((227845, 30), (56962, 30))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
#


# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Amount'], X_train['Time'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Amount'], X_train_scaled['Time'],color='red')
ax2.set_title("After Scaling")
plt.show()

# %%
# --- 5. Create Boxplots ---
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 8))

    # --- Before Scaling ---
ax1.set_title('Before Scaling')
sns.boxplot(data=X_train[['Time','Amount']], ax=ax1)
ax1.set_xlabel('Feature')
ax1.set_ylabel('Value')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90) 

    # --- After Scaling ---
ax2.set_title('After Standard Scaling')
sns.boxplot(data=X_train_scaled[['Time','Amount']], ax=ax2)
ax2.set_xlabel('Feature')
ax2.set_ylabel('Value')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90) 

    # --- Save and Show ---
plt.tight_layout() # Adjust plots to prevent overlap
plt.savefig('boxplot_before_after_scaling.png')
print("Saved 'boxplot_before_after_scaling.png'")
print("\nNote: The 'Before' plot's Y-axis is dominated by 'Amount'.")
print("The 'After' plot shows all features on a similar scale.")
# Out:
# C:\Users\Buymacs\AppData\Local\Temp\ipykernel_9348\4043921437.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# C:\Users\Buymacs\AppData\Local\Temp\ipykernel_9348\4043921437.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
# Saved 'boxplot_before_after_scaling.png'
#
# Note: The 'Before' plot's Y-axis is dominated by 'Amount'.
# The 'After' plot shows all features on a similar scale.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# --- Create a 2x2 Plot Grid ---
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))

# --- 1. Time (Before Scaling) ---
sns.kdeplot(X_train['Time'], ax=axes[0, 0], shade=True)
axes[0, 0].set_title('Time (Before Scaling)')
axes[0, 0].set_xlabel('Time (seconds)')
axes[0, 0].set_ylabel('Density')

# --- 2. Time (After Scaling) ---
sns.kdeplot(X_train_scaled['Time'], ax=axes[0, 1], shade=True)
axes[0, 1].set_title('Time (After Scaling)')
axes[0, 1].set_xlabel('Scaled Time (Z-score)')
axes[0, 1].set_ylabel('Density')

# --- 3. Amount (Before Scaling) ---
sns.kdeplot(X_train['Amount'], ax=axes[1, 0], shade=True)
axes[1, 0].set_title('Amount (Before Scaling)')
axes[1, 0].set_xlabel('Amount ($)')
axes[1, 0].set_ylabel('Density')
axes[1, 0].set_xlim(-200, 2000) # Zoom in to see the main distribution

# --- 4. Amount (After Scaling) ---
sns.kdeplot(X_train_scaled['Amount'], ax=axes[1, 1], shade=True)
axes[1, 1].set_title('Amount (After Scaling)')
axes[1, 1].set_xlabel('Scaled Amount (Z-score)')
axes[1, 1].set_ylabel('Density')
axes[1, 1].set_xlim(-5, 5) # Zoom in to see the main distribution

plt.tight_layout() # Prevents plots from overlapping
plt.show()
# Out:
# C:\Users\Buymacs\AppData\Local\Temp\ipykernel_9348\2852305265.py:11: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(X_train['Time'], ax=axes[0, 0], shade=True)
# C:\Users\Buymacs\AppData\Local\Temp\ipykernel_9348\2852305265.py:17: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(X_train_scaled['Time'], ax=axes[0, 1], shade=True)
# C:\Users\Buymacs\AppData\Local\Temp\ipykernel_9348\2852305265.py:23: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(X_train['Amount'], ax=axes[1, 0], shade=True)
# C:\Users\Buymacs\AppData\Local\Temp\ipykernel_9348\2852305265.py:30: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(X_train_scaled['Amount'], ax=axes[1, 1], shade=True)

# %%
df['Class'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Class Distribution (Pie Chart)")
plt.ylabel("")
plt.show()

# %%
# !pip install -U scikit-learn
# !pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\buymacs\appdata\local\programs\python\python313\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\buymacs\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\buymacs\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\buymacs\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\buymacs\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Buymacs\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Buymacs\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Buymacs\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: imbalanced-learn in c:\users\buymacs\appdata\local\programs\python\python313\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\buymacs\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (2.3.3)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\buymacs\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (1.16.2)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\buymacs\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (1.7.2)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\buymacs\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\buymacs\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (3.6.0)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Buymacs\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Buymacs\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Buymacs\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

# We use your 'y_train' to see the shape before balancing
print(f"Original training dataset shape: {Counter(y_train)}")

# Define SMOTE
smote = SMOTE(random_state=42)

# Apply SMOTE to your scaled training data
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train)

# Show the new, balanced shape
print(f"Resampled training dataset shape: {Counter(y_train_resampled)}")

# --- Optional: Visualize the new balanced data ---
print("\nVisualizing the balanced training data:")
plt.figure(figsize=(6, 4))
sns.countplot(x=y_train_resampled)
plt.title('Class Distribution After SMOTE')
plt.xlabel('Class (0 = No Fraud, 1 = Fraud)')
plt.ylabel('Count')
plt.show()
# Out:
# Original training dataset shape: Counter({0: 227454, 1: 391})
# Resampled training dataset shape: Counter({0: 227454, 1: 227454})
#
# Visualizing the balanced training data:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, average_precision_score
import matplotlib.pyplot as plt
import seaborn as sns

# -------------------------------
# 1. Select Correct Training Data
# -------------------------------
# If resampled data exists, use it. Otherwise use normal train data.
try:
    X_train_final = X_train_resampled
    y_train_final = y_train_resampled
    print("Using resampled training data.")
except NameError:
    X_train_final = X_train_scaled
    y_train_final = y_train
    print("Resampled data not found. Using original training data.")

# -------------------------------
# 2. Initialize & Train Model
# -------------------------------
model_lr = LogisticRegression(random_state=42, max_iter=1000)
print("Training Logistic Regression model...")
model_lr.fit(X_train_final, y_train_final)
print("Model trained successfully.")
print("-" * 40)

# -------------------------------
# 3. Make Predictions
# -------------------------------
predictions_lr = model_lr.predict(X_test_scaled)

# Probabilities for AUPRC
probs_lr = model_lr.predict_proba(X_test_scaled)[:, 1]

# -------------------------------
# 4. Model Evaluation
# -------------------------------

# A. AUPRC Score
auprc_lr = average_precision_score(y_test, probs_lr)
print(f"** Logistic Regression AUPRC: {auprc_lr:.4f} **")
print("This is your most important metric!")
print("-" * 40)

# B. Classification Report
print("\nClassification Report (Logistic Regression):")
print(classification_report(y_test, predictions_lr, 
                            target_names=['Non-Fraud (0)', 'Fraud (1)']))
print("-" * 40)

# C. Confusion Matrix
print("\nConfusion Matrix (Logistic Regression):")
cm_lr = confusion_matrix(y_test, predictions_lr)

plt.figure()
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.title('Logistic Regression Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Using resampled training data.
# Training Logistic Regression model...
# Model trained successfully.
# ----------------------------------------
# ** Logistic Regression AUPRC: 0.7670 **
# This is your most important metric!
# ----------------------------------------
#
# Classification Report (Logistic Regression):
#                precision    recall  f1-score   support
#
# Non-Fraud (0)       1.00      0.97      0.99     56861
#     Fraud (1)       0.06      0.94      0.12       101
#
#      accuracy                           0.97     56962
#     macro avg       0.53      0.96      0.55     56962
#  weighted avg       1.00      0.97      0.99     56962
#
# ----------------------------------------
#
# Confusion Matrix (Logistic Regression):

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, average_precision_score
import seaborn as sns
import matplotlib.pyplot as plt
import time

# --- 1. Train the Model (using normal scaled data) ---
model_knn = KNeighborsClassifier(n_neighbors=5)

print("Training KNN model...")
start_time = time.time()

model_knn.fit(X_train_scaled, y_train)

end_time = time.time()
print(f"Model trained successfully in {end_time - start_time:.2f} seconds.")
print("-" * 30)

# --- 2. Make Predictions ---
print("Making predictions with KNN...")
start_time = time.time()

predictions_knn = model_knn.predict(X_test_scaled)

# Probabilities for AUPRC
probs_knn = model_knn.predict_proba(X_test_scaled)[:, 1]

end_time = time.time()
print(f"Predictions made in {end_time - start_time:.2f} seconds.")
print("-" * 30)

# --- 3. Evaluate the Model ---

# A. AUPRC
auprc_knn = average_precision_score(y_test, probs_knn)
print(f"** KNN AUPRC: {auprc_knn:.4f} **")
print("-" * 30)

# B. Classification Report
print("\nClassification Report (KNN):")
print(classification_report(
    y_test,
    predictions_knn,
    target_names=['Non-Fraud (0)', 'Fraud (1)']
))
print("-" * 30)

# C. Confusion Matrix
print("\nConfusion Matrix (KNN):")
cm_knn = confusion_matrix(y_test, predictions_knn)

plt.figure()
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.title('KNN Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Training KNN model...
# Model trained successfully in 0.17 seconds.
# ------------------------------
# Making predictions with KNN...
# Predictions made in 136.44 seconds.
# ------------------------------
# ** KNN AUPRC: 0.7948 **
# ------------------------------
#
# Classification Report (KNN):
#                precision    recall  f1-score   support
#
# Non-Fraud (0)       1.00      1.00      1.00     56861
#     Fraud (1)       0.90      0.80      0.85       101
#
#      accuracy                           1.00     56962
#     macro avg       0.95      0.90      0.92     56962
#  weighted avg       1.00      1.00      1.00     56962
#
# ------------------------------
#
# Confusion Matrix (KNN):

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, average_precision_score
import seaborn as sns
import matplotlib.pyplot as plt
import time

# --- 1. Train the Model (using normal scaled data) ---
model_nb = GaussianNB()

print("Training Gaussian Naive Bayes model...")
start_time = time.time()

model_nb.fit(X_train_scaled, y_train)

end_time = time.time()
print(f"Model trained successfully in {end_time - start_time:.2f} seconds.")
print("-" * 30)

# --- 2. Make Predictions ---
print("Making predictions with Naive Bayes...")
start_time = time.time()

predictions_nb = model_nb.predict(X_test_scaled)

# Probabilities for AUPRC
probs_nb = model_nb.predict_proba(X_test_scaled)[:, 1]

end_time = time.time()
print(f"Predictions made in {end_time - start_time:.2f} seconds.")
print("-" * 30)

# --- 3. Evaluate the Model ---

# A. AUPRC
auprc_nb = average_precision_score(y_test, probs_nb)
print(f"** Gaussian Naive Bayes AUPRC: {auprc_nb:.4f} **")
print("-" * 30)

# B. Classification Report
print("\nClassification Report (Gaussian Naive Bayes):")
print(classification_report(
    y_test,
    predictions_nb,
    target_names=['Non-Fraud (0)', 'Fraud (1)']
))
print("-" * 30)

# C. Confusion Matrix
print("\nConfusion Matrix (Gaussian Naive Bayes):")
cm_nb = confusion_matrix(y_test, predictions_nb)

plt.figure()
sns.heatmap(cm_nb, annot=True, fmt='d', cmap='Purples',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.title('Gaussian Naive Bayes Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Training Gaussian Naive Bayes model...
# Model trained successfully in 0.28 seconds.
# ------------------------------
# Making predictions with Naive Bayes...
# Predictions made in 0.14 seconds.
# ------------------------------
# ** Gaussian Naive Bayes AUPRC: 0.0854 **
# ------------------------------
#
# Classification Report (Gaussian Naive Bayes):
#                precision    recall  f1-score   support
#
# Non-Fraud (0)       1.00      0.98      0.99     56861
#     Fraud (1)       0.07      0.85      0.12       101
#
#      accuracy                           0.98     56962
#     macro avg       0.53      0.91      0.56     56962
#  weighted avg       1.00      0.98      0.99     56962
#
# ------------------------------
#
# Confusion Matrix (Gaussian Naive Bayes):

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, average_precision_score
import seaborn as sns
import matplotlib.pyplot as plt
import time

# --- 1. Train the Model (using normal scaled data) ---
model_rf = RandomForestClassifier(
    random_state=42,
    n_jobs=-1,
    max_depth=8,
    min_samples_leaf=10
)

print("Training Random Forest model...")
start_time = time.time()

model_rf.fit(X_train_scaled, y_train)

end_time = time.time()
print(f"Model trained successfully in {end_time - start_time:.2f} seconds.")
print("-" * 30)

# --- 2. Make Predictions ---
print("Making predictions with Random Forest...")
start_time = time.time()

predictions_rf = model_rf.predict(X_test_scaled)

# Probabilities for AUPRC
probs_rf = model_rf.predict_proba(X_test_scaled)[:, 1]

end_time = time.time()
print(f"Predictions made in {end_time - start_time:.2f} seconds.")
print("-" * 30)

# --- 3. Evaluate the Model ---

# A. AUPRC
auprc_rf = average_precision_score(y_test, probs_rf)
print(f"** Random Forest AUPRC: {auprc_rf:.4f} **")
print("-" * 30)

# B. Classification Report
print("\nClassification Report (Random Forest):")
print(classification_report(
    y_test,
    predictions_rf,
    target_names=['Non-Fraud (0)', 'Fraud (1)']
))
print("-" * 30)

# C. Confusion Matrix
print("\nConfusion Matrix (Random Forest):")
cm_rf = confusion_matrix(y_test, predictions_rf)

plt.figure()
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.title('Random Forest Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Training Random Forest model...
# Model trained successfully in 63.26 seconds.
# ------------------------------
# Making predictions with Random Forest...
# Predictions made in 0.32 seconds.
# ------------------------------
# ** Random Forest AUPRC: 0.8366 **
# ------------------------------
#
# Classification Report (Random Forest):
#                precision    recall  f1-score   support
#
# Non-Fraud (0)       1.00      1.00      1.00     56861
#     Fraud (1)       0.90      0.73      0.81       101
#
#      accuracy                           1.00     56962
#     macro avg       0.95      0.87      0.90     56962
#  weighted avg       1.00      1.00      1.00     56962
#
# ------------------------------
#
# Confusion Matrix (Random Forest):

# %%
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

print(f"Original training dataset shape: {Counter(y_train)}")

# Define RandomUnderSampler
rus = RandomUnderSampler(random_state=42)

# Apply undersampling to your scaled training data
X_train_resampled_under, y_train_resampled_under = rus.fit_resample(X_train_scaled, y_train)

# Show the new, balanced shape
print(f"Resampled training dataset shape: {Counter(y_train_resampled_under)}")

# --- Optional: Visualize the new balanced data ---
print("\nVisualizing the balanced training data:")
plt.figure(figsize=(6, 4))
sns.countplot(x=y_train_resampled_under)
plt.title('Class Distribution After Random Undersampling')
plt.xlabel('Class (0 = No Fraud, 1 = Fraud)')
plt.ylabel('Count')
plt.show()
# Out:
# Original training dataset shape: Counter({0: 227454, 1: 391})
# Resampled training dataset shape: Counter({0: 391, 1: 391})
#
# Visualizing the balanced training data:

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, average_precision_score
import seaborn as sns
import matplotlib.pyplot as plt
import time

# --- 1. Initialize and Train the Model ---
model_rf = RandomForestClassifier(
    random_state=42,
    n_jobs=-1,
    max_depth=8,
    min_samples_leaf=10
)

print("Training Random Forest model...")
start_time = time.time()

model_rf.fit(X_train_scaled, y_train)

end_time = time.time()
print(f"Model trained successfully in {end_time - start_time:.2f} seconds.")
print("-" * 30)

# --- 2. Make Predictions ---
print("Making predictions with Random Forest...")
start_time = time.time()

predictions_rf = model_rf.predict(X_test_scaled)

# Get probabilities for the AUPRC score
probs_rf = model_rf.predict_proba(X_test_scaled)[:, 1]

end_time = time.time()
print(f"Predictions made in {end_time - start_time:.2f} seconds.")
print("-" * 30)

# --- 3. Evaluate the Model ---

# A. AUPRC
auprc_rf = average_precision_score(y_test, probs_rf)
print(f"** Random Forest AUPRC: {auprc_rf:.4f} **")
print("-" * 30)

# B. Classification Report
print("\nClassification Report (Random Forest):")
print(classification_report(
    y_test,
    predictions_rf,
    target_names=['Non-Fraud (0)', 'Fraud (1)']
))
print("-" * 30)

# C. Confusion Matrix
print("\nConfusion Matrix (Random Forest):")
cm_rf = confusion_matrix(y_test, predictions_rf)

plt.figure()
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.title('Random Forest Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Training Random Forest model...
# Model trained successfully in 66.80 seconds.
# ------------------------------
# Making predictions with Random Forest...
# Predictions made in 0.28 seconds.
# ------------------------------
# ** Random Forest AUPRC: 0.8366 **
# ------------------------------
#
# Classification Report (Random Forest):
#                precision    recall  f1-score   support
#
# Non-Fraud (0)       1.00      1.00      1.00     56861
#     Fraud (1)       0.90      0.73      0.81       101
#
#      accuracy                           1.00     56962
#     macro avg       0.95      0.87      0.90     56962
#  weighted avg       1.00      1.00      1.00     56962
#
# ------------------------------
#
# Confusion Matrix (Random Forest):

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, average_precision_score
import seaborn as sns
import matplotlib.pyplot as plt
import time

# --- 1. Train the Model (using normal scaled data) ---
model_nb = GaussianNB()

print("Training Gaussian Naive Bayes model...")
start_time = time.time()

model_nb.fit(X_train_scaled, y_train)

end_time = time.time()
print(f"Model trained successfully in {end_time - start_time:.2f} seconds.")
print("-" * 30)

# --- 2. Make Predictions ---
print("Making predictions with Naive Bayes...")
start_time = time.time()

predictions_nb = model_nb.predict(X_test_scaled)

# Probabilities for the AUPRC score
probs_nb = model_nb.predict_proba(X_test_scaled)[:, 1]

end_time = time.time()
print(f"Predictions made in {end_time - start_time:.2f} seconds.")
print("-" * 30)

# --- 3. Evaluate the Model ---

# A. AUPRC
auprc_nb = average_precision_score(y_test, probs_nb)
print(f"** Gaussian Naive Bayes AUPRC: {auprc_nb:.4f} **")
print("-" * 30)

# B. Classification Report
print("\nClassification Report (Gaussian Naive Bayes):")
print(classification_report(
    y_test,
    predictions_nb,
    target_names=['Non-Fraud (0)', 'Fraud (1)']
))
print("-" * 30)

# C. Confusion Matrix
print("\nConfusion Matrix (Gaussian Naive Bayes):")
cm_nb = confusion_matrix(y_test, predictions_nb)

plt.figure()
sns.heatmap(cm_nb, annot=True, fmt='d', cmap='Purples',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.title('Gaussian Naive Bayes Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Training Gaussian Naive Bayes model...
# Model trained successfully in 0.21 seconds.
# ------------------------------
# Making predictions with Naive Bayes...
# Predictions made in 0.13 seconds.
# ------------------------------
# ** Gaussian Naive Bayes AUPRC: 0.0854 **
# ------------------------------
#
# Classification Report (Gaussian Naive Bayes):
#                precision    recall  f1-score   support
#
# Non-Fraud (0)       1.00      0.98      0.99     56861
#     Fraud (1)       0.07      0.85      0.12       101
#
#      accuracy                           0.98     56962
#     macro avg       0.53      0.91      0.56     56962
#  weighted avg       1.00      0.98      0.99     56962
#
# ------------------------------
#
# Confusion Matrix (Gaussian Naive Bayes):

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, average_precision_score
import seaborn as sns
import matplotlib.pyplot as plt
import time

# --- 1. Train the Model ---
model_knn = KNeighborsClassifier(n_neighbors=5)

print("Training KNN model...")
start_time = time.time()

model_knn.fit(X_train_scaled, y_train)

end_time = time.time()
print(f"Model trained in {end_time - start_time:.2f} seconds.")
print("-" * 30)

# --- 2. Make Predictions ---
print("Making predictions with KNN...")
start_time = time.time()

predictions_knn = model_knn.predict(X_test_scaled)
probs_knn = model_knn.predict_proba(X_test_scaled)[:, 1]

end_time = time.time()
print(f"Predictions completed in {end_time - start_time:.2f} seconds.")
print("-" * 30)

# --- 3. Evaluation ---

# A. AUPRC
auprc_knn = average_precision_score(y_test, probs_knn)
print(f"KNN AUPRC: {auprc_knn:.4f}")
print("-" * 30)

# B. Classification Report
print("\nClassification Report (KNN):")
print(classification_report(
    y_test,
    predictions_knn,
    target_names=['Non-Fraud (0)', 'Fraud (1)']
))
print("-" * 30)

# C. Confusion Matrix
cm_knn = confusion_matrix(y_test, predictions_knn)

plt.figure()
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.title('KNN Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Training KNN model...
# Model trained in 0.09 seconds.
# ------------------------------
# Making predictions with KNN...
# Predictions completed in 137.78 seconds.
# ------------------------------
# KNN AUPRC: 0.7948
# ------------------------------
#
# Classification Report (KNN):
#                precision    recall  f1-score   support
#
# Non-Fraud (0)       1.00      1.00      1.00     56861
#     Fraud (1)       0.90      0.80      0.85       101
#
#      accuracy                           1.00     56962
#     macro avg       0.95      0.90      0.92     56962
#  weighted avg       1.00      1.00      1.00     56962
#
# ------------------------------

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, average_precision_score
import seaborn as sns
import matplotlib.pyplot as plt

# --- 1. Train the Model ---
model_lr = LogisticRegression(random_state=42, max_iter=1000)

print("Training Logistic Regression model...")
model_lr.fit(X_train_scaled, y_train)
print("Model trained successfully.")
print("-" * 30)

# --- 2. Make Predictions ---
predictions_lr = model_lr.predict(X_test_scaled)

# Probabilities for AUPRC
probs_lr = model_lr.predict_proba(X_test_scaled)[:, 1]

# --- 3. Evaluate the Model ---

# A. AUPRC
auprc_lr = average_precision_score(y_test, probs_lr)
print(f"Logistic Regression AUPRC: {auprc_lr:.4f}")
print("-" * 30)

# B. Classification Report
print("\nClassification Report (Logistic Regression):")
print(classification_report(
    y_test,
    predictions_lr,
    target_names=['Non-Fraud (0)', 'Fraud (1)']
))
print("-" * 30)

# C. Confusion Matrix
cm_lr = confusion_matrix(y_test, predictions_lr)

plt.figure()
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.title('Logistic Regression Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Training Logistic Regression model...
# Model trained successfully.
# ------------------------------
# Logistic Regression AUPRC: 0.7921
# ------------------------------
#
# Classification Report (Logistic Regression):
#                precision    recall  f1-score   support
#
# Non-Fraud (0)       1.00      1.00      1.00     56861
#     Fraud (1)       0.89      0.62      0.73       101
#
#      accuracy                           1.00     56962
#     macro avg       0.94      0.81      0.87     56962
#  weighted avg       1.00      1.00      1.00     56962
#
# ------------------------------

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# --- Import all the models ---
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# --- 1. Define the models ---
models = {
    "Logistic Regression": LogisticRegression(random_state=42, max_iter=1000),
    "Random Forest": RandomForestClassifier(random_state=42, n_jobs=-1, max_depth=8, min_samples_leaf=10),
    "Naive Bayes": GaussianNB(),
    "K-Nearest Neighbors": KNeighborsClassifier()
}

roc_auc_scores = {}

# --- 2. Plot the ROC curves ---
plt.figure(figsize=(10, 8))

for name, model in models.items():
    print(f"Training {name}...")
    model.fit(X_train_resampled, y_train_resampled)
    y_probs = model.predict_proba(X_test_scaled)[:, 1]
    roc_auc = roc_auc_score(y_test, y_probs)
    roc_auc_scores[name] = roc_auc
    fpr, tpr, _ = roc_curve(y_test, y_probs)
    plt.plot(fpr, tpr, lw=2, label=f'{name} (AUC = {roc_auc:.4f})') # Changed to 4 decimal places

# --- 3. Customize the plot ---
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve Comparison')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# --- 4. Print the scores ---
print("\n--- Model AUC Scores ---")
for name, score in roc_auc_scores.items():
    print(f'{name}: AUC - ROC = {score:.4f}')
# Out:
# Training Logistic Regression...
# Training Random Forest...
# Training Naive Bayes...
# Training K-Nearest Neighbors...
# --- Model AUC Scores ---
# Logistic Regression: AUC - ROC = 0.9862
# Random Forest: AUC - ROC = 0.9851
# Naive Bayes: AUC - ROC = 0.9694
# K-Nearest Neighbors: AUC - ROC = 0.9402
